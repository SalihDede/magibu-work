# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Unsloth Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh --local
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 2391, done.
# remote: Counting objects: 100% (2391/2391), done.
# remote: Compressing objects: 100% (2210/2210), done.
# remote: Total 2391 (delta 204), reused 1227 (delta 152), pack-reused 0 (from 0)
# Receiving objects: 100% (2391/2391), 40.36 MiB | 14.81 MiB/s, done.
# Resolving deltas: 100% (204/204), done.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  local mode: overlaying /content/unsloth (editable) + unsloth-zoo from git main
#                  installing isolated Node (system Node/npm left untouched)...
#   node           v24.18.0 | npm 11.16.0 (isolated)
#                  installing bun...
#                  bun installed (1.3.14)
#                  building frontend...
#                  using bun for package install (faster)
#   frontend       built
#                  Colab detected, installing Unsloth backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [==------------------]  2/15  base packages
#   deps           overlaying local repo (editable): /content/unsloth
#   deps           overlaying unsloth-zoo from git main
#   deps           [========------------]  6/15  dependency overrides   torch 2.10.0+cu128 detected -- installing torchao==0.16.0
#   deps           [====================] 15/15  torch final (cuda)
#   deps           installed
#   transformers   5.3.0 pre-installed
#   transformers   5.5.0 pre-installed
#   transformers   5.10.2 pre-installed
#   gpu            NVIDIA GPU detected
#                  installing prebuilt llama.cpp...
#   llama.cpp      prebuilt installed and validated
#                  installed release: unslothai/llama.cpp@b10069-mix-fb3d4ca (tag b10069)
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start

# Default: in-tab iframe only. start() blocks to keep the kernel alive.
start()

# For a shareable Cloudflare link, replace start() above with:
# start(cloudflare=True)
# Out:
# 2026-07-21 13:11:10 [info     ] 🦥 Starting Unsloth Studio...
# 2026-07-21 13:11:10 [info     ]    Loading backend...
# 2026-07-21 13:11:10 [info     ]    Starting server...
# 2026-07-21 13:11:10 [info     ] run_server startup begin api_only=False host=0.0.0.0 port=8888
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# {"timestamp": "2026-07-21T13:11:34.953409Z", "level": "info", "event": "Imported FastAPI app in 24675.1ms"}
# {"timestamp": "2026-07-21T13:11:34.956214Z", "level": "info", "event": "Ensured Unsloth directories in 24844.2ms"}
# {"timestamp": "2026-07-21T13:11:35.177332Z", "level": "info", "event": "run_server pre-uvicorn setup completed in 25065.3ms"}
# INFO:     Started server process [560]
# INFO:     Waiting for application startup.
# {"timestamp": "2026-07-21T13:11:35.484270Z", "level": "info", "event": "Removing unsloth compiled cache: /content/unsloth/unsloth_compiled_cache"}
# Hardware detected: CUDA -- NVIDIA A100-SXM4-40GB
# {"timestamp": "2026-07-21T13:11:35.485970Z", "level": "info", "event": "lifespan hardware detection completed in 1.8ms"}
# {"timestamp": "2026-07-21T13:11:35.824245Z", "level": "info", "event": "lifespan pre-auth setup completed in 340.1ms"}
#
# ============================================================
# DEFAULT ADMIN ACCOUNT CREATED
#     username: unsloth
#     password saved to: /root/.unsloth/studio/auth/.bootstrap_password
#     Open the Unsloth UI to sign in and change it.
# ============================================================
#
# {"timestamp": "2026-07-21T13:11:35.994619Z", "level": "info", "event": "lifespan startup completed in 510.5ms"}
# INFO:     Application startup complete.
# INFO:     Unsloth Studio running on http://35.240.149.78:8888 (To stop: press Ctrl+C -- on macOS, Control+C not Command+C)
# {"timestamp": "2026-07-21T13:11:35.997391Z", "level": "info", "event": "Uvicorn startup hook completed in 25885.3ms"}
# {"timestamp": "2026-07-21T13:11:35.998672Z", "level": "info", "event": "run_server uvicorn ready after 25886.6ms"}
# {"timestamp": "2026-07-21T13:11:36.006749Z", "level": "info", "event": "   Server started on port 8888!"}
# {"timestamp": "2026-07-21T13:11:36.291662Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 282.95}
# {"timestamp": "2026-07-21T13:11:38.605054Z", "level": "info", "event": "\ud83c\udf10 Unsloth Studio URL: https://8888-gpu-a100-s-kkb-ass1c1-mxvm6okxdmnq-c.asia-southeast1-1.prod.colab.dev"}
# <div style="font-family:system-ui,-apple-system,sans-serif;margin:8px 0;
#             border-radius:12px;overflow:hidden;box-shadow:0 2px 16px rgba(0,0,0,0.18);">
#   <div style="display:flex;align-items:center;gap:10px;padding:10px 16px;background:#000;">
#     <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#          height="26" style="display:block;">
#     <span style="color:#fff;font-weight:700;font-size:15px;letter-spacing:-0.2px;">Unsloth Studio</span>
#     <span style="margin-left:auto;color:#666;font-size:11px;font-family:monospace;">https://8888-gpu-...</span>
#   </div>
#   <iframe
#     id="unsloth-studio-8888"
#     src="https://8888-gpu-a100-s-kkb-ass1c1-mxvm6okxdmnq-c.asia-southeast1-1.prod.colab.dev"
#     style="width:100%;height:82vh;min-height:600px;max-height:1100px;border:none;display:block;box-sizing:border-box;"
#     allow="clipboard-read; clipboard-write"
#   ></iframe>
# </div>
# {"timestamp": "2026-07-21T13:11:39.213974Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 2.76}
# {"timestamp": "2026-07-21T13:11:39.659118Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/theme-boot.js", "status_code": 200, "process_time_ms": 33.59}
# {"timestamp": "2026-07-21T13:11:40.784145Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# {"timestamp": "2026-07-21T13:11:48.307361Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1.28}
# {"timestamp": "2026-07-21T13:11:49.102191Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 3.0}
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# {"timestamp": "2026-07-21T13:13:37.157489Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 84.9}
# {"timestamp": "2026-07-21T13:13:37.780454Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/change-password", "status_code": 200, "process_time_ms": 164.88}
# {"timestamp": "2026-07-21T13:13:38.190922Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 2.35}
# {"timestamp": "2026-07-21T13:13:38.235729Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/personalization", "status_code": 200, "process_time_ms": 4.47}
# {"timestamp": "2026-07-21T13:13:38.260838Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/settings", "status_code": 200, "process_time_ms": 3.27}
# {"timestamp": "2026-07-21T13:13:38.265416Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/rag/knowledge-bases", "status_code": 200, "process_time_ms": 10.62}
# {"timestamp": "2026-07-21T13:13:38.277561Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-07-21T13:13:38.287334Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 15.33}
# {"timestamp": "2026-07-21T13:13:38.291647Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 3.61}
# {"timestamp": "2026-07-21T13:13:38.596870Z", "level": "info", "event": "Top GGUF models: ['unsloth/Qwen3.6-27B-MTP-GGUF', 'unsloth/gemma-4-26B-A4B-it-GGUF', 'unsloth/Qwen3.5-4B-GGUF', 'unsloth/Qwen3.5-9B-GGUF', 'unsloth/Qwen3.6-35B-A3B-GGUF', 'unsloth/Qwen3.6-27B-GGUF', 'unsloth/Qwen-AgentWorld-35B-A3B-GGUF', 'unsloth/gemma-4-12b-it-GGUF', 'unsloth/Qwen3.6-35B-A3B-MTP-GGUF', 'unsloth/gemma-4-E4B-it-GGUF', 'unsloth/gemma-4-31B-it-GGUF', 'unsloth/gemma-4-26B-A4B-it-qat-GGUF', 'unsloth/gpt-oss-20b-GGUF', 'unsloth/GLM-5.2-GGUF', 'unsloth/Qwen3-VL-2B-Instruct-GGUF', 'unsloth/gemma-4-E2B-it-GGUF', 'unsloth/Kimi-K2.7-Code-GGUF', 'unsloth/Qwen3-Coder-30B-A3B-Instruct-GGUF', 'unsloth/gemma-4-31B-it-qat-GGUF', 'unsloth/Qwen3-8B-GGUF', 'unsloth/LTX-2.3-GGUF', 'unsloth/Qwen3.5-0.8B-GGUF', 'unsloth/bge-small-en-v1.5-GGUF', 'unsloth/gemma-4-12B-it-qat-GGUF', 'unsloth/Qwen2.5-VL-7B-Instruct-GGUF', 'unsloth/gemma-4-E4B-it-qat-GGUF', 'unsloth/Qwen-Image-Edit-2511-GGUF', 'unsloth/Qwen3-Coder-Next-GGUF', 'unsloth/Qwen3.5-35B-A3B-GGUF', 'unsloth/Qwen3-VL-4B-Instruct-GGUF', 'unsloth/FLUX.2-klein-4B-GGUF', 'unsloth/Qwen3.5-2B-GGUF', 'unsloth/Qwen3-30B-A3B-Instruct-2507-GGUF', 'unsloth/gpt-oss-120b-GGUF', 'unsloth/Qwen3-235B-A22B-GGUF', 'unsloth/FLUX.2-klein-9B-GGUF', 'unsloth/Qwen3.5-27B-GGUF', 'unsloth/Qwen3-0.6B-GGUF', 'unsloth/SmolLM2-135M-Instruct-GGUF', 'unsloth/Qwen3.5-9B-MTP-GGUF']"}
# {"timestamp": "2026-07-21T13:13:38.598193Z", "level": "info", "event": "Top hub models: ['unsloth/Qwen3.6-27B-NVFP4', 'unsloth/Qwen3.6-35B-A3B-NVFP4', 'unsloth/gemma-4-31B-it-unsloth-bnb-4bit', 'unsloth/Qwen3-VL-32B-Instruct-bnb-4bit', 'unsloth/Qwen2.5-3B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen2.5-14B-Instruct', 'unsloth/gemma-4-E4B-it-unsloth-bnb-4bit', 'unsloth/mistral-7b-v0.3-bnb-4bit', 'unsloth/Qwen2.5-7B-Instruct-bnb-4bit', 'unsloth/Meta-Llama-3.1-8B-Instruct', 'unsloth/Llama-3.1-8B-Instruct', 'unsloth/Qwen3-Embedding-4B', 'unsloth/GLM-4.7-Flash', 'unsloth/Qwen3.6-35B-A3B-NVFP4-Fast', 'unsloth/Llama-3.2-1B-Instruct', 'unsloth/Qwen3-14B-unsloth-bnb-4bit', 'unsloth/Qwen3-VL-4B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen2.5-14B-bnb-4bit', 'unsloth/gemma-3-4b-it', 'unsloth/GLM-4.5-Air', 'unsloth/Qwen3-VL-2B-Instruct-unsloth-bnb-4bit', 'unsloth/medgemma-27b-text-it-bnb-4bit', 'unsloth/Qwen3.5-4B', 'unsloth/Qwen3.5-9B', 'unsloth/gemma-4-12b-it', 'unsloth/bge-small-en-v1.5', 'unsloth/Qwen3-8B-unsloth-bnb-4bit', 'unsloth/Qwen3.5-2B', 'unsloth/Llama-3.2-3B-Instruct', 'unsloth/Qwen3-8B', 'unsloth/tinyllama-bnb-4bit', 'unsloth/gemma-4-31B-it-qat-w4a16', 'unsloth/gemma-4-E4B-it', 'unsloth/Qwen2.5-7B-Instruct', 'unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit', 'unsloth/Qwen2.5-7B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen2.5-Coder-7B-Instruct-bnb-4bit', 'unsloth/gpt-oss-20b-BF16']"}
# {"timestamp": "2026-07-21T13:13:38.626403Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.55}
# {"timestamp": "2026-07-21T13:13:39.419174Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 5.46}
# {"timestamp": "2026-07-21T13:13:39.422794Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-07-21T13:13:39.423760Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-07-21T13:13:39.424628Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 4.35}
# {"timestamp": "2026-07-21T13:13:39.730904Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 5.1}
# {"timestamp": "2026-07-21T13:13:40.446687Z", "level": "info", "event": "ExportOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-07-21T13:13:41.712582Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 4.33}
# {"timestamp": "2026-07-21T13:13:42.733364Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/checkpoints", "status_code": 200, "process_time_ms": 2.63}
# {"timestamp": "2026-07-21T13:13:42.757833Z", "level": "info", "event": "TrainingBackend initialized (subprocess mode)"}
# {"timestamp": "2026-07-21T13:13:42.773745Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/upload-limit", "status_code": 200, "process_time_ms": 3.9}
# {"timestamp": "2026-07-21T13:13:42.800556Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/system/hardware", "status_code": 200, "process_time_ms": 60.12}
# {"timestamp": "2026-07-21T13:13:43.405075Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/update-status", "status_code": 200, "process_time_ms": 175.84}
# {"timestamp": "2026-07-21T13:13:43.955369Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/update-status", "status_code": 200, "process_time_ms": 176.42}
# {"timestamp": "2026-07-21T13:13:53.309188Z", "level": "info", "event": "Getting model config for: unsloth/gemma-4-E4B-it"}
# {"timestamp": "2026-07-21T13:13:53.313222Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E4B-it.yaml (via mapping)"}
# config.json: 0.00B [00:00, ?B/s]
# {"timestamp": "2026-07-21T13:13:55.613702Z", "level": "info", "event": "Model config result for unsloth/gemma-4-E4B-it: is_vision=True, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=131072"}
# {"timestamp": "2026-07-21T13:13:55.870609Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/gemma-4-E4B-it", "status_code": 200, "process_time_ms": 2564.62}
# {"timestamp": "2026-07-21T13:14:42.139103Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/token/validate", "status_code": 200, "process_time_ms": 249.48}
# {"timestamp": "2026-07-21T13:15:30.546881Z", "level": "info", "event": "Checking format for dataset: SalihHub/trendyol-marangoz-urun-asistan-qa"}
# {"timestamp": "2026-07-21T13:15:30.857289Z", "level": "info", "event": "Tier 1: loading single file data/train.jsonl"}
# README.md: 0.00B [00:00, ?B/s]
# {"timestamp": "2026-07-21T13:15:35.610057Z", "level": "info", "event": "Checking format for dataset: SalihHub/trendyol-marangoz-urun-asistan-qa"}
# {"timestamp": "2026-07-21T13:15:35.897015Z", "level": "info", "event": "Tier 1: loading single file data/train.jsonl"}
# {"timestamp": "2026-07-21T13:15:36.199296Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-07-21T13:15:36.202043Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 5658.98}
# {"timestamp": "2026-07-21T13:15:38.481232Z", "level": "info", "event": "Format check result: requires_mapping=False, format=chatml, is_image=False"}
# {"timestamp": "2026-07-21T13:15:38.485021Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2877.3}
# {"timestamp": "2026-07-21T13:16:05.745531Z", "level": "info", "event": "Checking format for dataset: SalihHub/trendyol-marangoz-urun-asistan-qa"}
# {"timestamp": "2026-07-21T13:16:05.985112Z", "level": "info", "event": "Tier 1: loading single file data/train.jsonl"}
# {"timestamp": "2026-07-21T13:16:08.075395Z", "level": "info", "event": "Format check result: requires_mapping=False, format=chatml, is_image=False"}
# {"timestamp": "2026-07-21T13:16:08.079561Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2336.34}
# ={"timestamp": "2026-07-21T13:18:34.424338Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/token/validate", "status_code": 200, "process_time_ms": 3.67}
# {"timestamp": "2026-07-21T13:18:36.067882Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/token/validate", "status_code": 200, "process_time_ms": 3.14}
# {"timestamp": "2026-07-21T13:18:43.782681Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/token/validate", "status_code": 200, "process_time_ms": 3.31}
# {"timestamp": "2026-07-21T13:18:44.027050Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/token/validate", "status_code": 200, "process_time_ms": 3.28}
# {"timestamp": "2026-07-21T13:18:58.665308Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/token/validate", "status_code": 200, "process_time_ms": 3.28}
# {"timestamp": "2026-07-21T13:19:05.380631Z", "level": "info", "event": "Checking format for dataset: SalihHub/trendyol-marangoz-urun-asistan-qa"}
# {"timestamp": "2026-07-21T13:19:05.385360Z", "level": "info", "event": "Checking format for dataset: SalihHub/trendyol-marangoz-urun-asistan-qa"}
# {"timestamp": "2026-07-21T13:19:05.404688Z", "level": "info", "event": "Checking format for dataset: SalihHub/trendyol-marangoz-urun-asistan-qa"}
# {"timestamp": "2026-07-21T13:19:05.408839Z", "level": "info", "event": "Checking format for dataset: SalihHub/trendyol-marangoz-urun-asistan-qa"}
# {"timestamp": "2026-07-21T13:19:05.412224Z", "level": "info", "event": "Checking format for dataset: SalihHub/trendyol-marangoz-urun-asistan-qa"}
# {"timestamp": "2026-07-21T13:19:05.622469Z", "level": "info", "event": "Tier 1: loading single file data/train.jsonl"}
# {"timestamp": "2026-07-21T13:19:05.648405Z", "level": "info", "event": "Tier 1: loading single file data/train.jsonl"}
# {"timestamp": "2026-07-21T13:19:05.662600Z", "level": "info", "event": "Tier 1: loading single file data/train.jsonl"}
# {"timestamp": "2026-07-21T13:19:05.665568Z", "level": "info", "event": "Tier 1: loading single file data/train.jsonl"}
# {"timestamp": "2026-07-21T13:19:05.670119Z", "level": "info", "event": "Tier 1: loading single file data/train.jsonl"}
# {"timestamp": "2026-07-21T13:19:07.629351Z", "level": "info", "event": "Format check result: requires_mapping=False, format=chatml, is_image=False"}
# {"timestamp": "2026-07-21T13:19:07.634774Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2256.13}
# {"timestamp": "2026-07-21T13:19:07.671349Z", "level": "info", "event": "Format check result: requires_mapping=False, format=chatml, is_image=False"}
# {"timestamp": "2026-07-21T13:19:07.674814Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2291.27}
# {"timestamp": "2026-07-21T13:19:08.362445Z", "level": "info", "event": "Format check result: requires_mapping=False, format=chatml, is_image=False"}
# {"timestamp": "2026-07-21T13:19:08.389259Z", "level": "info", "event": "Format check result: requires_mapping=False, format=chatml, is_image=False"}
# {"timestamp": "2026-07-21T13:19:08.419704Z", "level": "info", "event": "Format check result: requires_mapping=False, format=chatml, is_image=False"}
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# processor_config.json: 0.00B [00:00, ?B/s]
# {"timestamp": "2026-07-21T13:19:12.813836Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E4B-it.yaml (via mapping)"}
# {"timestamp": "2026-07-21T13:19:13.083917Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/models/remote-code-scan", "status_code": 200, "process_time_ms": 5017.48}
# {"timestamp": "2026-07-21T13:19:15.832987Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E4B-it.yaml (via mapping)"}
# {"timestamp": "2026-07-21T13:19:16.100182Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/models/remote-code-scan", "status_code": 200, "process_time_ms": 3013.27}
# {"timestamp": "2026-07-21T13:19:16.107639Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.34}
# {"timestamp": "2026-07-21T13:19:16.109015Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 10704.96}
# {"timestamp": "2026-07-21T13:19:16.110387Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 10708.25}
# {"timestamp": "2026-07-21T13:19:16.112815Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 10704.78}
# {"timestamp": "2026-07-21T13:19:16.117101Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/token/validate", "status_code": 200, "process_time_ms": 3.1}
# {"timestamp": "2026-07-21T13:19:16.477655Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/token/validate", "status_code": 200, "process_time_ms": 3.02}
# {"timestamp": "2026-07-21T13:19:19.262973Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E4B-it.yaml (via mapping)"}
# {"timestamp": "2026-07-21T13:19:19.524723Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/models/remote-code-scan", "status_code": 200, "process_time_ms": 2976.4}
# {"timestamp": "2026-07-21T13:19:22.251179Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E4B-it.yaml (via mapping)"}
# {"timestamp": "2026-07-21T13:19:22.517127Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/models/remote-code-scan", "status_code": 200, "process_time_ms": 2990.43}
# {"timestamp": "2026-07-21T13:19:25.174299Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E4B-it.yaml (via mapping)"}
# {"timestamp": "2026-07-21T13:19:25.442659Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/models/remote-code-scan", "status_code": 200, "process_time_ms": 2924.31}
# {"timestamp": "2026-07-21T13:19:25.448303Z", "level": "info", "event": "Starting training job with model: unsloth/gemma-4-E4B-it"}
# {"timestamp": "2026-07-21T13:19:25.455516Z", "level": "info", "event": "Starting training job with model: unsloth/gemma-4-E4B-it"}
# {"timestamp": "2026-07-21T13:19:25.461518Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E4B-it.yaml (via mapping)"}
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# {"timestamp": "2026-07-21T13:19:44.514165Z", "level": "info", "event": "Training subprocess started (pid=5061)"}
# {"timestamp": "2026-07-21T13:19:44.524979Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 19081.29}
# {"timestamp": "2026-07-21T13:19:44.529181Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E4B-it.yaml (via mapping)"}
# {"timestamp": "2026-07-21T13:19:44.529981Z", "level": "warning", "event": "Training subprocess already running"}
# {"timestamp": "2026-07-21T13:19:44.531158Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 19077.08}
# {"timestamp": "2026-07-21T13:19:44.544362Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/token/validate", "status_code": 200, "process_time_ms": 9.91}
# {"timestamp": "2026-07-21T13:19:44.546493Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/token/validate", "status_code": 200, "process_time_ms": 8.89}
# {"timestamp": "2026-07-21T13:19:44.547876Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/token/validate", "status_code": 200, "process_time_ms": 7.04}
# {"timestamp": "2026-07-21T13:19:44.909353Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 4.4}
# {"timestamp": "2026-07-21T13:19:44.935788Z", "level": "info", "event": "Starting training job with model: unsloth/gemma-4-E4B-it"}
# {"timestamp": "2026-07-21T13:19:44.937184Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 3.12}
# {"timestamp": "2026-07-21T13:19:44.940065Z", "level": "info", "event": "Starting training job with model: unsloth/gemma-4-E4B-it"}
# {"timestamp": "2026-07-21T13:19:44.941066Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 2.6}
# {"timestamp": "2026-07-21T13:19:44.944014Z", "level": "info", "event": "Starting training job with model: unsloth/gemma-4-E4B-it"}
# {"timestamp": "2026-07-21T13:19:44.944909Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 2.26}
# {"timestamp": "2026-07-21T13:19:46.881706Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs/job_20260721_131925_c97a79fc", "status_code": 200, "process_time_ms": 5.47}
# {"timestamp": "2026-07-21T13:19:47.167577Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 284.86}
# {"timestamp": "2026-07-21T13:19:47.437443Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 268.81}
# {"timestamp": "2026-07-21T13:19:58.297377Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 2.46}
# {"timestamp": "2026-07-21T13:19:58.300623Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.82}
# {"timestamp": "2026-07-21T13:20:05.268716Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.74}
# {"timestamp": "2026-07-21T13:20:05.356386Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 4.44}
# {"timestamp": "2026-07-21T13:20:09.349328Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.16}
# {"timestamp": "2026-07-21T13:20:09.354678Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 2.17}
# {"timestamp": "2026-07-21T13:20:15.358351Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 4.09}
# {"timestamp": "2026-07-21T13:20:19.847893Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.19}
# {"timestamp": "2026-07-21T13:20:19.851983Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 2.36}
# {"timestamp": "2026-07-21T13:20:31.272381Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.2}
# {"timestamp": "2026-07-21T13:20:31.278164Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 2.27}
# {"timestamp": "2026-07-21T13:20:34.499162Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 4.89}
# {"timestamp": "2026-07-21T13:20:42.348653Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.44}
# {"timestamp": "2026-07-21T13:20:42.352678Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 2.27}
# {"timestamp": "2026-07-21T13:20:44.500077Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 4.8}
# {"timestamp": "2026-07-21T13:20:52.846318Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.0}
# {"timestamp": "2026-07-21T13:20:55.278673Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 4.11}
# {"timestamp": "2026-07-21T13:21:01.975472Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.41}
# {"timestamp": "2026-07-21T13:21:03.358034Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.24}
# {"timestamp": "2026-07-21T13:21:06.977760Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 4.32}
# {"timestamp": "2026-07-21T13:21:13.849530Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.17}
# {"timestamp": "2026-07-21T13:21:21.982027Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 13.36}
# {"timestamp": "2026-07-21T13:21:24.353647Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.15}
# {"timestamp": "2026-07-21T13:21:31.992800Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 25.1}
# {"timestamp": "2026-07-21T13:21:34.871480Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.21}
# ={"timestamp": "2026-07-21T13:21:42.249810Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 4.54}
# {"timestamp": "2026-07-21T13:21:45.348706Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.15}
# {"timestamp": "2026-07-21T13:21:55.848165Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.14}
# {"timestamp": "2026-07-21T13:22:07.270635Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.17}
# {"timestamp": "2026-07-21T13:22:36.289650Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.19}
# {"timestamp": "2026-07-21T13:22:48.649141Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.16}
# {"timestamp": "2026-07-21T13:22:58.983044Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.15}
# {"timestamp": "2026-07-21T13:23:21.349164Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.13}
# {"timestamp": "2026-07-21T13:24:21.295252Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.62}
# {"timestamp": "2026-07-21T13:24:51.548804Z", "level": "info", "event": "training_progress", "step": 1, "total_steps": 30, "percent": 3, "loss": 1.7008, "epoch": 0.01, "eta_s": 1895}
# {"timestamp": "2026-07-21T13:25:21.331866Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.24}
# {"timestamp": "2026-07-21T13:25:21.825283Z", "level": "info", "event": "training_progress", "step": 8, "total_steps": 30, "percent": 26, "loss": 1.1329, "epoch": 0.05, "eta_s": 262}
# {"timestamp": "2026-07-21T13:25:52.105074Z", "level": "info", "event": "training_progress", "step": 15, "total_steps": 30, "percent": 50, "loss": 0.9376, "epoch": 0.1, "eta_s": 125}
# {"timestamp": "2026-07-21T13:26:22.413674Z", "level": "info", "event": "training_progress", "step": 22, "total_steps": 30, "percent": 73, "loss": 0.7097, "epoch": 0.15, "eta_s": 56}
# ={"timestamp": "2026-07-21T13:26:52.823298Z", "level": "info", "event": "training_progress", "step": 29, "total_steps": 30, "percent": 96, "loss": 0.6087, "epoch": 0.19, "eta_s": 6}
# {"timestamp": "2026-07-21T13:26:57.088491Z", "level": "info", "event": "training_progress", "step": 30, "total_steps": 30, "percent": 100, "loss": 0.6793, "epoch": 0.2, "eta_s": null}
# {"timestamp": "2026-07-21T13:27:13.933577Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 446492.41}
# {"timestamp": "2026-07-21T13:27:25.153484Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 12.95}
# {"timestamp": "2026-07-21T13:27:25.157980Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.99}
# {"timestamp": "2026-07-21T13:27:44.739033Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 4.81}
# {"timestamp": "2026-07-21T13:27:44.757890Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/token/validate", "status_code": 200, "process_time_ms": 2.92}
# {"timestamp": "2026-07-21T13:27:44.781215Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/checkpoints", "status_code": 200, "process_time_ms": 2.48}
# {"timestamp": "2026-07-21T13:27:44.793735Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/token/validate", "status_code": 200, "process_time_ms": 6.12}
# {"timestamp": "2026-07-21T13:27:44.801542Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/token/validate", "status_code": 200, "process_time_ms": 2.74}
# {"timestamp": "2026-07-21T13:27:48.388308Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/export-size", "status_code": 200, "process_time_ms": 3214.98}
# {"timestamp": "2026-07-21T13:28:10.082366Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/export-size", "status_code": 200, "process_time_ms": 2.4}
# {"timestamp": "2026-07-21T13:29:19.573923Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/token/validate", "status_code": 200, "process_time_ms": 3.6}
# {"timestamp": "2026-07-21T13:29:20.378479Z", "level": "info", "event": "Spawning fresh export subprocess for '/root/.unsloth/studio/outputs/unsloth_gemma-4-E4B-it_1784640226'"}
# {"timestamp": "2026-07-21T13:29:20.386819Z", "level": "info", "event": "Export subprocess started (pid=7945)"}
# {"timestamp": "2026-07-21T13:29:20.611723Z", "level": "info", "event": "export_progress", "phase": "Importing Unsloth..."}
# {"timestamp": "2026-07-21T13:29:45.070245Z", "level": "info", "event": "export_progress", "phase": "Loading checkpoint: /root/.unsloth/studio/outputs/unsloth_gemma-4-E4B-it_1784640226"}
# {"timestamp": "2026-07-21T13:30:05.021597Z", "level": "info", "event": "Checkpoint '/root/.unsloth/studio/outputs/unsloth_gemma-4-E4B-it_1784640226' loaded in subprocess"}
# {"timestamp": "2026-07-21T13:30:05.023024Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/export/load-checkpoint", "status_code": 200, "process_time_ms": 44647.46}
# {"timestamp": "2026-07-21T13:30:05.901055Z", "level": "info", "event": "export_progress", "phase": "Exporting LoRA adapter..."}
# {"timestamp": "2026-07-21T13:30:37.229847Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/export/export/lora", "status_code": 200, "process_time_ms": 31333.07}
# {"timestamp": "2026-07-21T13:30:41.048657Z", "level": "info", "event": "Export subprocess shut down"}
# {"timestamp": "2026-07-21T13:30:41.050279Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/export/cleanup", "status_code": 200, "process_time_ms": 3415.85}
# {"timestamp": "2026-07-21T13:30:42.096249Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/export/logs/stream", "status_code": 200, "process_time_ms": 82109.14}
# {"timestamp": "2026-07-21T13:30:49.609574Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/export/logs/stream", "status_code": 200, "process_time_ms": 1111.84}
# {"timestamp": "2026-07-21T13:30:51.063194Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.74}
# {"timestamp": "2026-07-21T13:30:58.062497Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 6.99}
# {"timestamp": "2026-07-21T13:30:58.067872Z", "level": "info", "event": "Found 1 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-07-21T13:30:58.068948Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/gemma-4-e4b-it-unsloth-bnb-4bit"}
# {"timestamp": "2026-07-21T13:30:58.070873Z", "level": "info", "event": "Found 1 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-07-21T13:30:58.071989Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 7.01}
# {"timestamp": "2026-07-21T13:30:58.080745Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/recommended-folders", "status_code": 200, "process_time_ms": 4.33}
# {"timestamp": "2026-07-21T13:30:58.089643Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 7.86}
# {"timestamp": "2026-07-21T13:30:58.095283Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 4.84}
# {"timestamp": "2026-07-21T13:30:58.096909Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/hidden-models", "status_code": 200, "process_time_ms": 23.97}
# {"timestamp": "2026-07-21T13:30:58.101129Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/scan-folders", "status_code": 200, "process_time_ms": 2.82}
# {"timestamp": "2026-07-21T13:30:58.565815Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 30.36}
# {"timestamp": "2026-07-21T13:30:58.568930Z", "level": "info", "event": "Cached model scan: inspected=6 skipped_gguf=0 skipped_no_weights=0 returned=1"}
# {"timestamp": "2026-07-21T13:30:58.570997Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 33.87}
# {"timestamp": "2026-07-21T13:30:58.582974Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 51.09}
# {"timestamp": "2026-07-21T13:30:59.016938Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 21.75}
# {"timestamp": "2026-07-21T13:31:04.804749Z", "level": "info", "event": "Cached model scan: inspected=6 skipped_gguf=0 skipped_no_weights=0 returned=1"}
# {"timestamp": "2026-07-21T13:31:04.806261Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 10.35}
# {"timestamp": "2026-07-21T13:31:04.813777Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 4.81}
# {"timestamp": "2026-07-21T13:31:16.959537Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 5.51}
# {"timestamp": "2026-07-21T13:31:16.965581Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/scan-folders", "status_code": 200, "process_time_ms": 2.38}
# {"timestamp": "2026-07-21T13:31:16.970859Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 4.37}
# {"timestamp": "2026-07-21T13:31:16.976308Z", "level": "info", "event": "Found 1 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-07-21T13:31:16.977168Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/gemma-4-e4b-it-unsloth-bnb-4bit"}
# {"timestamp": "2026-07-21T13:31:16.978571Z", "level": "info", "event": "Found 1 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-07-21T13:31:16.979537Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 5.29}
# {"timestamp": "2026-07-21T13:31:16.985535Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 5.19}
# {"timestamp": "2026-07-21T13:31:16.988228Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/recommended-folders", "status_code": 200, "process_time_ms": 1.83}
# {"timestamp": "2026-07-21T13:31:17.019089Z", "level": "info", "event": "Cached model scan: inspected=6 skipped_gguf=0 skipped_no_weights=0 returned=1"}
# {"timestamp": "2026-07-21T13:31:17.021227Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 60.0}
# {"timestamp": "2026-07-21T13:31:17.022568Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 33.61}
# {"timestamp": "2026-07-21T13:31:17.034210Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 62.51}
# {"timestamp": "2026-07-21T13:31:26.550199Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/recommended-folders", "status_code": 200, "process_time_ms": 2.04}
# {"timestamp": "2026-07-21T13:31:26.557854Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/scan-folders", "status_code": 200, "process_time_ms": 2.46}
# {"timestamp": "2026-07-21T13:31:26.566164Z", "level": "info", "event": "Found 1 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-07-21T13:31:26.567187Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/gemma-4-e4b-it-unsloth-bnb-4bit"}
# {"timestamp": "2026-07-21T13:31:26.568834Z", "level": "info", "event": "Found 1 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-07-21T13:31:26.570071Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 5.73}
# {"timestamp": "2026-07-21T13:31:26.576415Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 5.66}
# {"timestamp": "2026-07-21T13:31:26.594993Z", "level": "info", "event": "Cached model scan: inspected=6 skipped_gguf=0 skipped_no_weights=0 returned=1"}
# {"timestamp": "2026-07-21T13:31:26.596793Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 14.59}
# {"timestamp": "2026-07-21T13:31:26.601719Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 21.23}
# {"timestamp": "2026-07-21T13:31:26.616635Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 38.92}
# {"timestamp": "2026-07-21T13:31:34.481298Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/token/validate", "status_code": 200, "process_time_ms": 3.43}
# {"timestamp": "2026-07-21T13:31:34.902345Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/gemma-4-e4b-it-unsloth-bnb-4bit"}
# {"timestamp": "2026-07-21T13:31:34.903281Z", "level": "info", "event": "Auto-detected local LoRA adapter at '/root/.unsloth/studio/exports/unsloth_gemma-4-E4B-it_1784640226/unsloth_gemma-4-E4B-it_1784640226' (base: unsloth/gemma-4-e4b-it-unsloth-bnb-4bit)"}
# {"timestamp": "2026-07-21T13:31:34.904393Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/gemma-4-e4b-it-unsloth-bnb-4bit"}
# {"timestamp": "2026-07-21T13:31:34.905749Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/gemma-4-e4b-it-unsloth-bnb-4bit"}
# {"timestamp": "2026-07-21T13:31:35.488509Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-07-21T13:31:35.497391Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-07-21T13:31:38.586425Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-07-21T13:31:38.591489Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# ={"timestamp": "2026-07-21T13:31:39.262509Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/validate", "status_code": 200, "process_time_ms": 4364.34}
# {"timestamp": "2026-07-21T13:31:39.744800Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/token/validate", "status_code": 200, "process_time_ms": 3.18}
# {"timestamp": "2026-07-21T13:31:40.257519Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/gemma-4-e4b-it-unsloth-bnb-4bit"}
# {"timestamp": "2026-07-21T13:31:40.258396Z", "level": "info", "event": "Auto-detected local LoRA adapter at '/root/.unsloth/studio/exports/unsloth_gemma-4-E4B-it_1784640226/unsloth_gemma-4-E4B-it_1784640226' (base: unsloth/gemma-4-e4b-it-unsloth-bnb-4bit)"}
# {"timestamp": "2026-07-21T13:31:40.259307Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/gemma-4-e4b-it-unsloth-bnb-4bit"}
# {"timestamp": "2026-07-21T13:31:40.261459Z", "level": "info", "event": "Transformers tier 550 selected for /root/.unsloth/studio/exports/unsloth_gemma-4-E4B-it_1784640226/unsloth_gemma-4-E4B-it_1784640226 (substring match: gemma-4)"}
# {"timestamp": "2026-07-21T13:31:40.262707Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/gemma-4-e4b-it-unsloth-bnb-4bit"}
# {"timestamp": "2026-07-21T13:31:40.263341Z", "level": "info", "event": "Auto-detected local LoRA adapter at '/root/.unsloth/studio/exports/unsloth_gemma-4-E4B-it_1784640226/unsloth_gemma-4-E4B-it_1784640226' (base: unsloth/gemma-4-e4b-it-unsloth-bnb-4bit)"}
# {"timestamp": "2026-07-21T13:31:40.263985Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/gemma-4-e4b-it-unsloth-bnb-4bit"}
# {"timestamp": "2026-07-21T13:31:40.794555Z", "level": "info", "event": "Spawning fresh inference subprocess for '/root/.unsloth/studio/exports/unsloth_gemma-4-E4B-it_1784640226/unsloth_gemma-4-E4B-it_1784640226' (transformers 5.x, attempt 1/2)"}
# {"timestamp": "2026-07-21T13:31:40.807188Z", "level": "info", "event": "Inference subprocess started (pid=8643)"}
# ...
# {"timestamp": "2026-07-21T13:37:20.804302Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages", "status_code": 200, "process_time_ms": 12.13}
# {"timestamp": "2026-07-21T13:37:21.163634Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.86}
# {"timestamp": "2026-07-21T13:37:21.180088Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/415o5hZ", "status_code": 200, "process_time_ms": 11.84}
# {"timestamp": "2026-07-21T13:37:21.552823Z", "level": "info", "event": "safetensors: model supports reasoning (enable_thinking)"}
# {"timestamp": "2026-07-21T13:37:21.553740Z", "level": "info", "event": "safetensors: model supports preserve_thinking"}
# {"timestamp": "2026-07-21T13:37:21.554343Z", "level": "info", "event": "safetensors: model supports tool calling"}
# {"timestamp": "2026-07-21T13:37:21.555381Z", "level": "info", "event": "safetensors: model supports reasoning (enable_thinking)"}
# {"timestamp": "2026-07-21T13:37:21.556085Z", "level": "info", "event": "safetensors: model supports preserve_thinking"}
# {"timestamp": "2026-07-21T13:37:21.558214Z", "level": "info", "event": "safetensors: model supports tool calling"}
# {"timestamp": "2026-07-21T13:37:27.721732Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/415o5hZ/forks", "status_code": 200, "process_time_ms": 2.8}
# {"timestamp": "2026-07-21T13:37:27.779160Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/nM9NGJ9/forks", "status_code": 200, "process_time_ms": 2.77}
# {"timestamp": "2026-07-21T13:37:50.520930Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/nM9NGJ9/forks", "status_code": 200, "process_time_ms": 2.83}
# {"timestamp": "2026-07-21T13:37:50.548793Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/415o5hZ/forks", "status_code": 200, "process_time_ms": 2.83}
# {"timestamp": "2026-07-21T13:38:01.838228Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/415o5hZ/forks", "status_code": 200, "process_time_ms": 2.89}
# {"timestamp": "2026-07-21T13:38:30.226807Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/415o5hZ/forks", "status_code": 200, "process_time_ms": 2.86}
# {"timestamp": "2026-07-21T13:38:52.242135Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 90692.84}
# {"timestamp": "2026-07-21T13:39:04.354527Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/415o5hZ/forks", "status_code": 200, "process_time_ms": 2.55}
# {"timestamp": "2026-07-21T13:39:04.370977Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/u7aZ0Jw/forks", "status_code": 200, "process_time_ms": 2.41}
# {"timestamp": "2026-07-21T13:39:04.376176Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.82}
# {"timestamp": "2026-07-21T13:39:04.379798Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/XKURzrS/forks", "status_code": 200, "process_time_ms": 2.33}
# {"timestamp": "2026-07-21T13:39:04.736147Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/415o5hZ/forks", "status_code": 200, "process_time_ms": 2.87}
# {"timestamp": "2026-07-21T13:39:04.752008Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.56}
# {"timestamp": "2026-07-21T13:39:29.732079Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/3bc4Gck/forks", "status_code": 200, "process_time_ms": 3.31}
# {"timestamp": "2026-07-21T13:39:41.499362Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 3.17}
# {"timestamp": "2026-07-21T13:39:41.849290Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/415o5hZ/forks", "status_code": 200, "process_time_ms": 3.95}
# {"timestamp": "2026-07-21T13:39:41.881888Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.36}
# {"timestamp": "2026-07-21T13:39:42.261566Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.77}
# {"timestamp": "2026-07-21T13:39:42.640392Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.86}
# {"timestamp": "2026-07-21T13:39:43.019139Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.79}
# {"timestamp": "2026-07-21T13:39:43.403607Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages", "status_code": 200, "process_time_ms": 3.87}
# {"timestamp": "2026-07-21T13:39:44.557654Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.81}
# {"timestamp": "2026-07-21T13:39:44.936415Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.86}
# {"timestamp": "2026-07-21T13:39:45.314640Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.81}
# {"timestamp": "2026-07-21T13:39:45.693427Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.82}
# {"timestamp": "2026-07-21T13:39:46.085975Z", "level": "info", "event": "safetensors: model supports reasoning (enable_thinking)"}
# {"timestamp": "2026-07-21T13:39:46.086823Z", "level": "info", "event": "safetensors: model supports preserve_thinking"}
# {"timestamp": "2026-07-21T13:39:46.087382Z", "level": "info", "event": "safetensors: model supports tool calling"}
# {"timestamp": "2026-07-21T13:39:46.088238Z", "level": "info", "event": "safetensors: model supports reasoning (enable_thinking)"}
# {"timestamp": "2026-07-21T13:39:46.089012Z", "level": "info", "event": "safetensors: model supports preserve_thinking"}
# {"timestamp": "2026-07-21T13:39:46.089794Z", "level": "info", "event": "safetensors: model supports tool calling"}
# {"timestamp": "2026-07-21T13:40:06.884120Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/415o5hZ/forks", "status_code": 200, "process_time_ms": 2.8}
# {"timestamp": "2026-07-21T13:40:51.548018Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/415o5hZ/forks", "status_code": 200, "process_time_ms": 2.85}
# {"timestamp": "2026-07-21T13:41:02.500768Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/415o5hZ/forks", "status_code": 200, "process_time_ms": 2.89}
# {"timestamp": "2026-07-21T13:41:12.503322Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/nM9NGJ9/forks", "status_code": 200, "process_time_ms": 2.79}
# {"timestamp": "2026-07-21T13:41:14.497620Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/3bc4Gck/forks", "status_code": 200, "process_time_ms": 3.04}
# {"timestamp": "2026-07-21T13:41:25.047225Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/3bc4Gck/forks", "status_code": 200, "process_time_ms": 2.82}
# {"timestamp": "2026-07-21T13:41:27.295223Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/3bc4Gck/forks", "status_code": 200, "process_time_ms": 2.87}
# {"timestamp": "2026-07-21T13:41:32.272400Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/3bc4Gck/forks", "status_code": 200, "process_time_ms": 2.85}
# {"timestamp": "2026-07-21T13:41:38.011748Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/3bc4Gck/forks", "status_code": 200, "process_time_ms": 2.98}
# ={"timestamp": "2026-07-21T13:41:46.097746Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/3bc4Gck/forks", "status_code": 200, "process_time_ms": 2.87}
# {"timestamp": "2026-07-21T13:41:53.426193Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/3bc4Gck/forks", "status_code": 200, "process_time_ms": 2.76}
# {"timestamp": "2026-07-21T13:42:04.071649Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.71}
# {"timestamp": "2026-07-21T13:42:04.991898Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 138909.85}
# {"timestamp": "2026-07-21T13:42:20.860166Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/3bc4Gck/forks", "status_code": 200, "process_time_ms": 3.05}
# {"timestamp": "2026-07-21T13:42:29.374077Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/u7aZ0Jw/forks", "status_code": 200, "process_time_ms": 2.53}
# {"timestamp": "2026-07-21T13:42:29.378536Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/XKURzrS/forks", "status_code": 200, "process_time_ms": 2.31}
# {"timestamp": "2026-07-21T13:42:29.382660Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/oTEMLHk/forks", "status_code": 200, "process_time_ms": 2.25}
# {"timestamp": "2026-07-21T13:42:29.390769Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.2}
# {"timestamp": "2026-07-21T13:42:29.840631Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.49}
# {"timestamp": "2026-07-21T13:42:30.249384Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages", "status_code": 200, "process_time_ms": 3.89}
# {"timestamp": "2026-07-21T13:42:30.256036Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.27}
# {"timestamp": "2026-07-21T13:42:30.657195Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.49}
# {"timestamp": "2026-07-21T13:42:31.078951Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/oTEMLHk", "status_code": 200, "process_time_ms": 13.45}
# {"timestamp": "2026-07-21T13:42:31.469480Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/oTEMLHk/forks", "status_code": 200, "process_time_ms": 2.9}
# {"timestamp": "2026-07-21T13:42:31.473434Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.46}
# {"timestamp": "2026-07-21T13:42:31.477066Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/u7aZ0Jw/forks", "status_code": 200, "process_time_ms": 2.37}
# {"timestamp": "2026-07-21T13:42:31.480477Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/XKURzrS/forks", "status_code": 200, "process_time_ms": 2.23}
# {"timestamp": "2026-07-21T13:42:31.844521Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/3bc4Gck/forks", "status_code": 200, "process_time_ms": 2.84}
# {"timestamp": "2026-07-21T13:42:31.852584Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.34}
# {"timestamp": "2026-07-21T13:42:32.232635Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p", "status_code": 200, "process_time_ms": 2.29}
# {"timestamp": "2026-07-21T13:42:32.648237Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages", "status_code": 200, "process_time_ms": 14.97}
# {"timestamp": "2026-07-21T13:42:33.035529Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/u7aZ0Jw/forks", "status_code": 200, "process_time_ms": 2.94}
# {"timestamp": "2026-07-21T13:42:33.039900Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/XKURzrS/forks", "status_code": 200, "process_time_ms": 2.62}
# {"timestamp": "2026-07-21T13:42:33.043653Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/oTEMLHk/forks", "status_code": 200, "process_time_ms": 2.48}
# {"timestamp": "2026-07-21T13:42:36.036821Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/3bc4Gck/forks", "status_code": 200, "process_time_ms": 3.34}
# {"timestamp": "2026-07-21T13:42:40.762587Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/3bc4Gck/forks", "status_code": 200, "process_time_ms": 2.89}
# {"timestamp": "2026-07-21T13:42:46.507938Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/3bc4Gck/forks", "status_code": 200, "process_time_ms": 2.82}
# {"timestamp": "2026-07-21T13:44:31.911192Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/3bc4Gck/forks", "status_code": 200, "process_time_ms": 2.89}
# {"timestamp": "2026-07-21T13:45:46.813700Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_DfWIQ7p/messages/3bc4Gck/forks", "status_code": 200, "process_time_ms": 3.14}

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
